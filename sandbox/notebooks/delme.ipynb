# %%
import numpy as np

# %%
results = {'metadata': 
           {'student_id': 'stu_p001', 'current_status': 'student3yr', 'education_level': 'bachelor', 'education_major': 'วิทยาการคอมพิวเตอร์', 'target_roles': 'Data Analyst', 'timezone': 'UTC', 'model_name': 'gemini-2.5-flash', 'max_output_tokens': 2048, 'feed_text_max_chars': 240, 'temperature': 0.2, 'interaction': [{'user_id': 'stu_p001', 'feed_id': 'TH_F008', 'ts': '2026-01-04 14:05:02+00:00', 'event_type': 'click', 'dwell_ms': '0'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F001', 'ts': '2026-01-06 13:14:30+00:00', 'event_type': 'comment', 'dwell_ms': '0'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F001', 'ts': '2026-01-06 13:13:05+00:00', 'event_type': 'like', 'dwell_ms': '0'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F017', 'ts': '2026-01-03 10:16:20+00:00', 'event_type': 'share', 'dwell_ms': '0'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F004', 'ts': '2026-01-01 11:35:50+00:00', 'event_type': 'view', 'dwell_ms': '24000'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F009', 'ts': '2026-01-04 14:06:40+00:00', 'event_type': 'view', 'dwell_ms': '38000'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F003', 'ts': '2026-01-05 09:20:11+00:00', 'event_type': 'view', 'dwell_ms': '41000'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F017', 'ts': '2026-01-03 10:15:33+00:00', 'event_type': 'view', 'dwell_ms': '46000'}, {'user_id': 'stu_p001', 'feed_id': 'TH_F001', 'ts': '2026-01-06 13:12:10+00:00', 'event_type': 'view', 'dwell_ms': '52000'}]}, 
           'hyde': 
           {'hyde_text01.txt': '', 'hyde_text02.txt': '', 'hyde_text03.txt': '', 'hyde_text04.txt': '', 'hyde_text05.txt': ''}, 
           'embeddings': 
           {'embedding01.npy': np.array([ 1.83219016e-02, -8.82829167e-03,  6.35276595e-03, -1.22597642e-01,
        2.25363602e-03,  2.97095124e-02,  2.28621042e-03,  1.24988407e-02],
      dtype=np.float32), 
      'embedding02.npy': np.array([ 6.55537331e-03, -3.13904285e-02,  1.72714749e-03, -1.16688319e-01,
        2.56185490e-03,  2.35074908e-02,  3.20733450e-02,  1.19177587e-02],
      dtype=np.float32), 
      'embedding03.npy': np.array([-1.43659313e-03,  1.89356133e-02, -6.52426388e-03, -9.79860350e-02,
        1.14997318e-02, -1.16496831e-02,  7.65902456e-03,  1.07894707e-02],
      dtype=np.float32), 
      'embedding04.npy': np.array([ 7.51728052e-03,  1.26729896e-02, -1.78197082e-02, -1.42484844e-01,
        7.32172932e-03,  2.41616722e-02,  5.32306917e-03, -7.43208919e-03],
      dtype=np.float32), 
      'embedding05.npy': np.array([ 3.30204464e-04,  1.95860676e-02,  8.66043102e-03, -1.23850130e-01,
        2.81210057e-03,  4.64331498e-03,  1.28112650e-02,  1.65808722e-02,
        2.59560562e-04,  3.90890576e-02,  2.12954618e-02, -1.59331989e-02],
      dtype=np.float32)}, 'status': 'hyde-datalake-feeds /\n|- stu_p001 /\n  |- metadata folder /\n    |- metadata.json /\n  |- hyde folder /\n    |- stu_p001/hyde/hyde_text01.txt x\n    |- stu_p001/hyde/hyde_text02.txt x\n    |- stu_p001/hyde/hyde_text03.txt x\n    |- stu_p001/hyde/hyde_text04.txt x\n    |- stu_p001/hyde/hyde_text05.txt x\n  |- embedding folder /\n    |- stu_p001/embedding/embedding01.npy /\n    |- stu_p001/embedding/embedding02.npy /\n    |- stu_p001/embedding/embedding03.npy /\n    |- stu_p001/embedding/embedding04.npy /\n    |- stu_p001/embedding/embedding05.npy /\n'}

# %%
results['embeddings']["embedding01.npy"]
results['embeddings']["embedding02.npy"]
results['embeddings']["embedding03.npy"]
results['embeddings']["embedding04.npy"]
results['embeddings']["embedding05.npy"]
# Out:
# array([ 0.0003302 ,  0.01958607,  0.00866043, -0.12385013,  0.0028121 ,
#         0.00464331,  0.01281126,  0.01658087,  0.00025956,  0.03908906,
#         0.02129546, -0.0159332 ], dtype=float32)

# %%
results["metadata"]
# Out:
# {'student_id': 'stu_p001',
#  'current_status': 'student3yr',
#  'education_level': 'bachelor',
#  'education_major': 'วิทยาการคอมพิวเตอร์',
#  'target_roles': 'Data Analyst',
#  'timezone': 'UTC',
#  'model_name': 'gemini-2.5-flash',
#  'max_output_tokens': 2048,
#  'feed_text_max_chars': 240,
#  'temperature': 0.2,
#  'interaction': [{'user_id': 'stu_p001',
#    'feed_id': 'TH_F008',
#    'ts': '2026-01-04 14:05:02+00:00',
#    'event_type': 'click',
#    'dwell_ms': '0'},
#   {'user_id': 'stu_p001',
#    'feed_id': 'TH_F001',
#    'ts': '2026-01-06 13:14:30+00:00',
#    'event_type': 'comment',
#    'dwell_ms': '0'},
#   {'user_id': 'stu_p001',
#    'feed_id': 'TH_F001',
#    'ts': '2026-01-06 13:13:05+00:00',
#    'event_type': 'like',
#    'dwell_ms': '0'},
#   {'user_id': 'stu_p001',
#    'feed_id': 'TH_F017',
#    'ts': '2026-01-03 10:16:20+00:00',
#    'event_type': 'share',
#    'dwell_ms': '0'},
#   {'user_id': 'stu_p001',
#    'feed_id': 'TH_F004',
# ...
