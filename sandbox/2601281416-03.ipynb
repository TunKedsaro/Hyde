# %%
# pip install db-dtypes

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()

# %%
query = """
SELECT *
FROM `poc-piloturl-nonprod.gold_layer.students`
"""

# %%
df = client.query(query).to_dataframe()
# Out:
# /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df
# Out:
#   student_id preferred_language current_status education_level  \
# 0   stu_p007                 th        newgrad        bachelor
# 1   stu_p006                 th     student2yr        bachelor
# 2   stu_p001                 th     student3yr        bachelor
# 3   stu_p009                 en     student3yr        bachelor
# 4   stu_p003                 th    student4+yr        bachelor
# 5   stu_p004                 th    student4+yr        bachelor
# 6   stu_p005                 th     student1yr        bachelor
# 7   stu_p002                 th     student2yr        bachelor
# 8   stu_p010                 th     student3yr        bachelor
# 9   stu_p008                 th     student0yr        bachelor
#
#              education_major                            target_roles  \
# 0          วิศวกรรมอุตสาหการ                        Quality Engineer
# 1                   ชีววิทยา                    Biotechnology Intern
# 2        วิทยาการคอมพิวเตอร์                            Data Analyst
# 3           Computer Science                            Data Analyst
# 4                      สถิติ                            Data Analyst
# 5               บริหารธุรกิจ                        Business Analyst
# 6        วิทยาการคอมพิวเตอร์                               Undecided
# 7            เทคโนโลยีชีวภาพ  Biotechnology Researcher|Lab Scientist
# 8  ความสัมพันธ์ระหว่างประเทศ                          Policy Analyst
# 9                นิเทศศาสตร์                               Undecided
#
#                                        skills  \
# 0              Statistics:L1;Documentation:L1
# 1  Biology Fundamentals:L1;Lab Skills:unknown
# 2                            Python:L2;SQL:L2
# 3                            SQL:L1;Python:L1
# 4         Statistics:L2;Excel:L2;Basic SQL:L1
# 5                    Excel:L2;Presentation:L1
# 6                                   Python:L1
# 7          Lab Skills:L1;Molecular Biology:L1
# 8                      Writing:L1;Research:L1
# 9                            Communication:L1
#
#                                interests onboard_grp  \
# 0                   เตรียมสัมภาษณ์;หางาน  Job_Hunter
# 1         ฝึกงาน;ทำพอร์ตสาย Bio;สมัครทุน  Job_Hunter
# 2                    ทำพอร์ต;ฝึกสัมภาษณ์  Job_Hunter
# 3         portfolio;internship;interview  Job_Hunter
# 4   เตรียมเรซูเม่;ฝึกสัมภาษณ์;ทำโปรเจกต์  Job_Hunter
# 5            หางาน;ทำเรซูเม่;ฝึกสัมภาษณ์  Job_Hunter
# 6          สำรวจสายอาชีพ;เรียนรู้พื้นฐาน     Learner
# 7             ทำวิจัย;ฝึกงานแลบ;สมัครทุน     Learner
# 8  สมัครทุน;ข่าวมหาวิทยาลัย;เส้นทางอาชีพ     Learner
# 9            ข่าวมหาวิทยาลัย;กิจกรรม;ทุน      Social
#
#                              onboard_grp_description
# 0                 เพิ่งจบและหางานสายคุณภาพ/กระบวนการ
# 1           อยากได้ฝึกงานสายชีวภาพและอยากเตรียมพอร์ต
# 2                              เตรียมฝึกงานสายข้อมูล
# 3  Looking for internship and building a data por...
# 4                 ใกล้จบและอยากสมัครงาน Data Analyst
# 5              ใกล้จบและกำลังหางานสายวิเคราะห์ธุรกิจ
# 6  ยังไม่ชัดเจน เป้าหมายคือสำรวจสายงานและสร้างพื้...
# 7         อยากทำวิจัยและเตรียมตัวเข้าฝึกงานสายชีวภาพ
# 8    สนใจทุนและเส้นทางอาชีพด้านนโยบาย (harder match)
# 9  นักศึกษาใหม่ ต้องการข่าวสารมหาวิทยาลัยและโอกาสทุน

# %%
query = """
SELECT *
FROM `poc-piloturl-nonprod.gold_layer.feeds`
"""
df = client.query(query).to_dataframe()
df
# Out:
# /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                    source                created_at  \
# 0         University News 2025-01-06 07:30:00+00:00
# 1           Campus Update 2025-01-04 08:20:00+00:00
# 2             Campus Life 2025-01-02 09:00:00+00:00
# 3        Academic Affairs 2025-12-31 10:00:00+00:00
# 4         Research Office 2025-12-29 08:30:00+00:00
# 5         Student Affairs 2025-12-27 07:50:00+00:00
# 6        Academic Advisor 2025-12-25 09:10:00+00:00
# 7           Industry Link 2025-12-23 08:40:00+00:00
# 8         Campus Calendar 2025-12-21 07:20:00+00:00
# 9         EduPolicy Watch 2025-12-19 09:00:00+00:00
# 10           BioCareer TH 2025-01-05 08:00:00+00:00
# 11                 BioEdu 2025-01-03 09:15:00+00:00
# 12        BioResearch Hub 2025-01-01 08:40:00+00:00
# 13              BioIntern 2025-12-30 07:50:00+00:00
# 14           LabSkills TH 2025-12-28 09:00:00+00:00
# 15                BioData 2025-12-26 08:30:00+00:00
# 16             EduCompare 2025-12-24 09:20:00+00:00
# 17           BioCareer TH 2025-12-22 08:10:00+00:00
# 18      BioIndustry Watch 2025-12-20 07:40:00+00:00
# 19                GradBio 2025-12-18 09:00:00+00:00
# 20          EduFunding TH 2025-01-06 08:30:00+00:00
# 21          Scholar Coach 2025-01-04 09:10:00+00:00
# 22        Global Study TH 2025-01-02 10:00:00+00:00
# 23         EduWriting Lab 2025-12-29 08:45:00+00:00
# 24            GradFunding 2025-12-27 09:30:00+00:00
# 25            Campus Life 2025-12-25 08:00:00+00:00
# 26          Scholar Coach 2025-12-23 07:40:00+00:00
# 27        Student Finance 2025-12-21 09:20:00+00:00
# 28           Research Hub 2025-12-19 10:10:00+00:00
# 29               EduGuide 2025-12-17 08:50:00+00:00
# 30           CareerHub TH 2025-01-05 09:00:00+00:00
# 31      DataCamp Thailand 2025-01-04 10:30:00+00:00
# 32         InternGuide TH 2025-01-03 08:00:00+00:00
# 33              UniCareer 2025-01-02 12:00:00+00:00
# 34           LearnData TH 2025-12-30 08:50:00+00:00
# 35              Stat4Data 2025-12-28 10:00:00+00:00
# 36        Interview Coach 2025-12-26 13:20:00+00:00
# 37        SQL Practice TH 2025-12-24 07:30:00+00:00
# 38              PyData TH 2025-12-22 09:00:00+00:00
# 39      Career Planner TH 2025-12-20 09:15:00+00:00
# 40      Experiment Lab TH 2025-12-18 12:10:00+00:00
# 41         AI Career Path 2025-12-16 09:40:00+00:00
# 42        PortfolioKit TH 2025-12-14 08:20:00+00:00
# 43        Interview Coach 2025-12-12 06:45:00+00:00
# 44           DevCareer TH 2025-12-10 11:00:00+00:00
# 45              PyData TH 2025-12-08 09:10:00+00:00
# 46        BusinessData TH 2025-12-06 07:55:00+00:00
# 47        SQL Practice TH 2025-12-04 08:30:00+00:00
# 48              UniCareer 2025-12-02 09:00:00+00:00
# 49           ResumeLab TH 2025-11-30 06:50:00+00:00
# 50           LearnData TH 2025-11-28 10:15:00+00:00
# 51         InternGuide TH 2025-11-26 07:05:00+00:00
# 52        Interview Coach 2025-11-24 09:40:00+00:00
# 53          AI Starter TH 2025-11-22 08:10:00+00:00
# 54        BusinessData TH 2025-11-20 07:25:00+00:00
# 55        PortfolioKit TH 2025-11-18 09:05:00+00:00
# 56     DataInterview Prep 2025-12-22 07:30:00+00:00
# 57       Analytics Career 2025-12-18 09:00:00+00:00
# 58            Intern Prep 2025-12-12 08:00:00+00:00
# 59  Product Analytics Lab 2025-11-25 09:00:00+00:00
#
#                                               tags  \
# 0               [university, admission, education]
# 1              [university, curriculum, education]
# 2                  [seminar, workshop, university]
# 3                       [policy, exam, university]
# 4                  [research, university, student]
# 5              [student-life, university, welfare]
# 6                 [curriculum, career, university]
# 7            [industry, collaboration, university]
# 8             [calendar, student-life, university]
# 9             [education-policy, university, news]
# 10                [biotechnology, career, science]
# 11             [biotechnology, education, biology]
# 12        [biotechnology, research, undergraduate]
# 13             [biotechnology, internship, career]
# 14          [biotechnology, lab-skills, education]
# 15  [bioinformatics, biotechnology, career-growth]
# 16         [biotechnology, curriculum, university]
# 17          [biotechnology, portfolio, internship]
# 18                [biotechnology, industry, trend]
# 19            [biotechnology, graduate, education]
# 20           [scholarship, undergraduate, funding]
# 21           [scholarship, application, education]
# 22           [exchange, scholarship, study-abroad]
# 23                     [sop, scholarship, writing]
# 24                [scholarship, graduate, science]
# 25         [scholarship, university, student-life]
# 26             [scholarship, interview, education]
# 27                 [finance, scholarship, student]
# 28          [research, scholarship, undergraduate]
# 29       [scholarship, decision-making, education]
# 30          [data-analyst, portfolio, python, sql]
# 31      [dashboard, data-visualization, portfolio]
# 32            [interview, internship, sql, python]
# 33           [internship, co-op, job-hunt, career]
# 34                [learning-roadmap, data-analyst]
# 35         [statistics, a-b-testing, data-analyst]
# 36           [interview, communication, portfolio]
# 37                      [sql, interview, practice]
# 38                          [python, project, eda]
# 39       [job-hunt, internship, resume, portfolio]
# 40              [a-b-testing, statistics, project]
# 41      [machine-learning, career-growth, project]
# 42                     [portfolio, resume, career]
# 43          [interview, behavioral, communication]
# 44                    [github, portfolio, project]
# 45                    [data-cleaning, python, eda]
# 46            [project, dashboard, kpi, portfolio]
# 47               [sql, window-function, interview]
# 48                        [co-op, project, career]
# 49                     [resume, ats, career, data]
# 50           [project, churn, portfolio, business]
# 51     [internship, job-hunt, portfolio, linkedin]
# 52  [take-home, internship, data-analyst, project]
# 53   [machine-learning, learning-roadmap, student]
# 54           [sql, business, analytics, interview]
# 55                    [portfolio, project, career]
# 56                  [sql, interview, data-analyst]
# 57             [portfolio, data-analytics, career]
# 58        [internship, interview, sql, case-study]
# 59    [a-b-testing, product-analytics, statistics]
#
#                                             feed_text  views  \
# 0   สรุปช่วงเวลารับสมัครนักศึกษาใหม่ของมหาวิทยาลัย...  68400
# 1   รวบรวมหลักสูตรเปิดใหม่ทั้งปริญญาตรีและบัณฑิตศึ...  51200
# 2   รวมข่าวกิจกรรมวิชาการ สัมมนา และ workshop ที่น...  46300
# 3   สรุปนโยบายการจัดการเรียนการสอน รูปแบบการสอบ แล...  16400
# 4   แนะนำช่องทางเข้าร่วมโปรเจกต์วิจัยกับอาจารย์ในม...  14250
# 5   อัปเดตทุนการศึกษา สวัสดิการ และบริการช่วยเหลือ...  13100
# 6   แนะแนวการเลือกวิชาเลือกให้สอดคล้องกับสายงานเป้...  11850
# 7   อัปเดตความร่วมมือระหว่างมหาวิทยาลัยกับภาคอุตสา...  10900
# 8   รวมกำหนดการกิจกรรมนักศึกษา วันสำคัญ และเดดไลน์...  10250
# 9   สรุปข่าวและทิศทางนโยบายการศึกษาระดับอุดมศึกษาใ...   9850
# 10  สรุปภาพรวมงานสาย Biotechnology เช่น งานวิจัย ง...  58700
# 11  แนะนำพื้นฐานสำคัญสำหรับการเรียน Biotechnology ...  54100
# 12  ตัวอย่างหัวข้อวิจัยสำหรับนักศึกษาปริญญาตรี ตั้...  49600
# 13  รวมโอกาสฝึกงานด้าน Biotechnology ในหน่วยงานรัฐ...  21400
# 14  สรุปทักษะห้องปฏิบัติการที่ใช้บ่อย เช่น cell cu...  19600
# 15  อธิบายแนวทางต่อยอดจาก Biotechnology ไปสู่ Bioi...  17850
# 16  แนวทางคัดเลือกหลักสูตร Biotechnology ในมหาวิทย...  16500
# 17  แนะนำการทำพอร์ตสาย Bio สำหรับยื่นฝึกงานหรือขอท...  15350
# 18  สรุปแนวโน้มอุตสาหกรรมชีวภาพ/ชีวการแพทย์ในประเท...  14600
# 19  แนวทางเตรียมเรียนต่อระดับบัณฑิตศึกษาในสายชีววิ...  13900
# 20  สรุปทุนการศึกษาปริญญาตรีที่นักศึกษาไทยสมัครได้...  73300
# 21  แนะแนวการเตรียมเอกสารสมัครทุน เช่น SOP, CV, re...  61800
# 22  ภาพรวมทุนแลกเปลี่ยนนักศึกษาต่างประเทศทั้งระยะส...  59400
# 23  เทคนิคเขียน Statement of Purpose สำหรับสมัครทุ...  18700
# 24  รวมทุนเรียนต่อระดับบัณฑิตศึกษาสำหรับสายวิทยาศา...  17100
# 25  เช็กลิสต์สำหรับสมัครทุนภายในมหาวิทยาลัย เช่น ท...  15800
# 26  รวบรวมคำถามสัมภาษณ์ทุนที่มักเจอ พร้อมแนวทางตอบ...  14900
# 27  คำแนะนำการวางแผนการเงินสำหรับผู้ได้รับทุน ครอบ...  13700
# 28  แนะนำทุนสนับสนุนงานวิจัยสำหรับนักศึกษาปริญญาตร...  12800
# 29  แนวทางเปรียบเทียบทุนหลายประเภท โดยดูเงื่อนไข ร...  12100
# 30  อธิบายวิธีเลือกโปรเจกต์ Python และ SQL สำหรับท...  81200
# 31  รวมตัวอย่างโปรเจกต์ Dashboard ที่เหมาะกับพอร์ต...  76500
# 32  สรุปแนวคำถามสัมภาษณ์ Data Analyst สำหรับฝึกงาน...  72400
# 33  เช็กลิสต์การเตรียมตัวสมัครฝึกงานหรือสหกิจสาย D...  69800
# 34  แผนการเรียนรู้ Data Analyst สำหรับนักศึกษา เริ...  42800
# 35  สรุปสถิติพื้นฐานที่ใช้จริง เช่น distribution, ...  39200
# 36  แนะนำโครงสร้างการเล่าโปรเจกต์ด้วย STAR และการเ...  37100
# 37  รวมโจทย์ SQL ฝึกสัมภาษณ์สำหรับฝึกงาน เช่น grou...  68400
# 38  แนวทางทำโปรเจกต์ Python สำหรับวิเคราะห์ข้อมูลจ...  55600
# 39  วิธีจัดลำดับบริษัทเป้าหมาย การปรับเรซูเม่และพอ...  51300
# 40  อธิบาย A/B testing สำหรับนักศึกษา ตั้งแต่ตั้งส...  44800
# 41  แนะนำโปรเจกต์เริ่มต้นเพื่อขยับไป ML Engineer เ...  42100
# 42  เทมเพลตโครงสร้างพอร์ตแบบ 1 หน้า: บทสรุป, เครื่...  40500
# 43  รวมคำถาม behavioral ที่พบบ่อย เช่น ทำงานเป็นที...  38900
# 44  แนวทางจัด GitHub สำหรับพอร์ตสาย Data: โครงสร้า...  37200
# 45  รวมเทคนิค data cleaning ที่ใช้บ่อย เช่น handli...  35800
# 46  ไอเดียโปรเจกต์สำหรับพอร์ต: วิเคราะห์ยอดขายรายห...  61200
# 47  สรุป window functions ที่ใช้บ่อย เช่น row_numb...  57700
# 48  แนวทางเลือกหัวข้อโปรเจกต์สหกิจให้สอดคล้องกับสา...  33600
# 49  อธิบายวิธีปรับคำในเรซูเม่และพอร์ตให้ ATS อ่านเ...  32400
# 50  สอนทำ mini project วิเคราะห์ churn แบบง่าย: ตั...  30900
# 51  เช็กลิสต์ก่อนส่งสมัครฝึกงาน: พอร์ตพร้อม, เรซูเ...  29600
# 52  ตัวอย่างโจทย์ take-home สำหรับฝึกงาน Data Anal...  28400
# 53  แนะนำการเริ่มเรียน Machine Learning สำหรับนักศ...  27100
# 54  สอนวิธีแปลงคำถามธุรกิจให้เป็น SQL query เช่น r...  45900
# 55  แนวทางเลือกจำนวนและประเภทโปรเจกต์ในพอร์ต (2–4 ...  26300
# 56  A curated list of common SQL interview questio...  31700
# 57  A practical guide to structuring a data analyt...  28900
# 58  Interview prep for data analyst internships co...  24800
# 59  An introduction to A/B testing for product ana...  22100
#
#                                                 title  \
# 0   ปฏิทินการรับเข้าศึกษาใหม่ของมหาวิทยาลัยไทย (อั...
# 1   อัปเดตสาขา/หลักสูตรใหม่ในมหาวิทยาลัยไทยประจำปีนี้
# 2   อัปเดตกิจกรรมวิชาการ สัมมนา และเวิร์กช็อปสำหรั...
# 3   สรุปกติกาเรียน-สอบ และแนวปฏิบัติของภาคการศึกษานี้
# 4   เปิดรับนักศึกษาป.ตรีร่วมทำวิจัยกับอาจารย์: สมั...
# 5   อัปเดตทุน/สวัสดิการนักศึกษาในมหาวิทยาลัย (สิทธ...
# 6   เลือกวิชาเลือกให้เข้าทางอาชีพ: เทคนิควางแผนราย...
# 7   ความร่วมมือมหาวิทยาลัย-ภาคอุตสาหกรรม: อัปเดตโค...
# 8   ปฏิทินกิจกรรมและวันสำคัญของนักศึกษา: สิ่งที่คว...
# 9   อัปเดตนโยบายอุดมศึกษาไทย: ประเด็นที่กระทบหลักส...
# 10  เส้นทางอาชีพด้าน Biotechnology สำหรับนักศึกษาไ...
# 11  จะเรียน Biotechnology ต้องพร้อมอะไร: พื้นฐานที...
# 12      ไอเดียหัวข้องานวิจัยชีวภาพสำหรับนักศึกษาป.ตรี
# 13  รวมที่ฝึกงานสาย Biotechnology ในไทย: ภาครัฐ เอ...
# 14  ทักษะห้องแล็บที่สาย Bio ควรมี: รายการสำคัญและก...
# 15  จาก Biotechnology สู่ Bioinformatics/Data Biol...
# 16  เลือกหลักสูตร Biotechnology ในมหาวิทยาลัยไทย: ...
# 17  จัดพอร์ตสาย Bio เพื่อสมัครฝึกงาน/ทุน: ต้องมีอะ...
# 18  เทรนด์อุตสาหกรรมชีวภาพและชีวการแพทย์ในไทย: โอก...
# 19  เตรียมตัวเรียนต่อโท-เอกสาย Bio/Biotech: วางแผน...
# 20     รวมทุนป.ตรีสำหรับนักศึกษาไทย (อัปเดตรอบล่าสุด)
# 21  เตรียมเอกสารสมัครทุนให้ผ่านรอบคัดกรอง: จุดที่ค...
# 22  ทุนแลกเปลี่ยนต่างประเทศ: เช็คก่อนสมัคร (ระยะสั...
# 23  เขียน SOP สมัครทุนให้เด่น: โครงเรื่อง เป้าหมาย...
# 24  ทุนเรียนต่อโท-เอกสายวิทย์/เทค/วิศวะ: เลือกทุนใ...
# 25  เช็กลิสต์สมัครทุนในมหาวิทยาลัย: เตรียมอะไรบ้าง...
# 26    สัมภาษณ์ทุน: คำถามยอดฮิตและแนวตอบให้ตรงโจทย์ทุน
# 27  บริหารเงินทุนให้พอทั้งปี: แผนการใช้จ่ายสำหรับน...
# 28  ทุนทำวิจัยสำหรับนักศึกษาป.ตรี: หาอาจารย์ที่ปรึ...
# 29  มีทุนหลายตัวให้เลือก: วิธีเทียบเงื่อนไขและตัดส...
# 30  แนวทางทำพอร์ต Data Analyst ด้วยโปรเจกต์ Python...
# 31   ไอเดียโปรเจกต์ Dashboard สำหรับนักศึกษาสายข้อมูล
# 32  เทคนิคเตรียมสัมภาษณ์ฝึกงาน Data Analyst (SQL +...
# 33      เช็กลิสต์สมัครฝึกงาน/สหกิจสาย Data สำหรับปี 3
# 34  Roadmap Data Analyst สำหรับนักศึกษา: เรียนอะไร...
# 35  พื้นฐานสถิติที่ใช้บ่อยในงาน Data Analyst (พร้อ...
# 36  วิธีเล่าโปรเจกต์ Data ให้โดนใจในการสัมภาษณ์ (S...
# 37  รวมโจทย์ SQL ฝึกสัมภาษณ์ระดับฝึกงาน (พร้อมเฉลย...
# 38  โปรเจกต์ Python วิเคราะห์ข้อมูลจริง: ตั้งแต่ทำ...
# 39  แนวทางสมัครงาน/ฝึกงานสาย Data: จัดลำดับบริษัทแ...
# 40  ทำ A/B Testing แบบเข้าใจง่ายสำหรับโปรเจกต์นักศ...
# 41  จาก Data Analyst ไป ML Engineer: โปรเจกต์เริ่ม...
# 42  โครงสร้างพอร์ต 1 หน้า: ใส่อะไรบ้างให้ recruite...
# 43  คำถามสัมภาษณ์ Behavioral สำหรับสาย Data (พร้อม...
# 44  แนะนำ GitHub สำหรับพอร์ตสาย Data: จัด repo และ...
# 45  ฝึกทำ Data Cleaning: เทคนิคจัดการ missing และ ...
# 46  Portfolio Project: วิเคราะห์ยอดขาย + สร้าง KPI...
# 47       SQL Window Functions แบบที่ใช้จริงในงาน Data
# 48  เตรียมตัวสหกิจ: วิธีเลือกหัวข้อโปรเจกต์ให้ได้ท...
# 49      How-to: เตรียมพอร์ตให้ผ่าน ATS สำหรับสาย Data
# 50  Mini Project: วิเคราะห์ churn แบบง่ายเพื่อใส่พ...
# 51  Checklist ก่อนส่งสมัครฝึกงาน: พอร์ต เรซูเม่ Gi...
# 52  Data Analyst Intern: ตัวอย่างโจทย์ Take-home แ...
# 53  เริ่มต้น Machine Learning แบบไม่หลงทาง: สิ่งที...
# 54  SQL + Business Thinking: แปลงคำถามธุรกิจเป็น q...
# 55  สาย Data ควรมีโปรเจกต์กี่ชิ้นในพอร์ต และควรเป็...
# 56  SQL Interview Questions for Entry-Level Data A...
# 57     How to Build a Strong Data Analytics Portfolio
# 58  Data Analyst Internship Interview Prep: SQL + ...
# 59           A/B Testing Basics for Product Analytics
#
#                                       embedding_input language  \
# 0   title: ปฏิทินการรับเข้าศึกษาใหม่ของมหาวิทยาลัย...       th
# 1   title: อัปเดตสาขา/หลักสูตรใหม่ในมหาวิทยาลัยไทย...       th
# 2   title: อัปเดตกิจกรรมวิชาการ สัมมนา และเวิร์กช็...       th
# 3   title: สรุปกติกาเรียน-สอบ และแนวปฏิบัติของภาคก...       th
# 4   title: เปิดรับนักศึกษาป.ตรีร่วมทำวิจัยกับอาจาร...       th
# 5   title: อัปเดตทุน/สวัสดิการนักศึกษาในมหาวิทยาลั...       th
# 6   title: เลือกวิชาเลือกให้เข้าทางอาชีพ: เทคนิควา...       th
# 7   title: ความร่วมมือมหาวิทยาลัย-ภาคอุตสาหกรรม: อ...       th
# 8   title: ปฏิทินกิจกรรมและวันสำคัญของนักศึกษา: สิ...       th
# 9   title: อัปเดตนโยบายอุดมศึกษาไทย: ประเด็นที่กระ...       th
# 10  title: เส้นทางอาชีพด้าน Biotechnology สำหรับนั...       th
# 11  title: จะเรียน Biotechnology ต้องพร้อมอะไร: พื...       th
# 12  title: ไอเดียหัวข้องานวิจัยชีวภาพสำหรับนักศึกษ...       th
# 13  title: รวมที่ฝึกงานสาย Biotechnology ในไทย: ภา...       th
# 14  title: ทักษะห้องแล็บที่สาย Bio ควรมี: รายการสำ...       th
# 15  title: จาก Biotechnology สู่ Bioinformatics/Da...       th
# 16  title: เลือกหลักสูตร Biotechnology ในมหาวิทยาล...       th
# 17  title: จัดพอร์ตสาย Bio เพื่อสมัครฝึกงาน/ทุน: ต...       th
# 18  title: เทรนด์อุตสาหกรรมชีวภาพและชีวการแพทย์ในไ...       th
# 19  title: เตรียมตัวเรียนต่อโท-เอกสาย Bio/Biotech:...       th
# 20  title: รวมทุนป.ตรีสำหรับนักศึกษาไทย (อัปเดตรอบ...       th
# 21  title: เตรียมเอกสารสมัครทุนให้ผ่านรอบคัดกรอง: ...       th
# 22  title: ทุนแลกเปลี่ยนต่างประเทศ: เช็คก่อนสมัคร ...       th
# 23  title: เขียน SOP สมัครทุนให้เด่น: โครงเรื่อง เ...       th
# 24  title: ทุนเรียนต่อโท-เอกสายวิทย์/เทค/วิศวะ: เล...       th
# 25  title: เช็กลิสต์สมัครทุนในมหาวิทยาลัย: เตรียมอ...       th
# 26  title: สัมภาษณ์ทุน: คำถามยอดฮิตและแนวตอบให้ตรง...       th
# 27  title: บริหารเงินทุนให้พอทั้งปี: แผนการใช้จ่าย...       th
# 28  title: ทุนทำวิจัยสำหรับนักศึกษาป.ตรี: หาอาจารย...       th
# 29  title: มีทุนหลายตัวให้เลือก: วิธีเทียบเงื่อนไข...       th
# 30  title: แนวทางทำพอร์ต Data Analyst ด้วยโปรเจกต์...       th
# 31  title: ไอเดียโปรเจกต์ Dashboard สำหรับนักศึกษา...       th
# 32  title: เทคนิคเตรียมสัมภาษณ์ฝึกงาน Data Analyst...       th
# 33  title: เช็กลิสต์สมัครฝึกงาน/สหกิจสาย Data สำหร...       th
# 34  title: Roadmap Data Analyst สำหรับนักศึกษา: เร...       th
# 35  title: พื้นฐานสถิติที่ใช้บ่อยในงาน Data Analys...       th
# 36  title: วิธีเล่าโปรเจกต์ Data ให้โดนใจในการสัมภ...       th
# 37  title: รวมโจทย์ SQL ฝึกสัมภาษณ์ระดับฝึกงาน (พร...       th
# 38  title: โปรเจกต์ Python วิเคราะห์ข้อมูลจริง: ตั...       th
# 39  title: แนวทางสมัครงาน/ฝึกงานสาย Data: จัดลำดับ...       th
# 40  title: ทำ A/B Testing แบบเข้าใจง่ายสำหรับโปรเจ...       th
# 41  title: จาก Data Analyst ไป ML Engineer: โปรเจก...       th
# 42  title: โครงสร้างพอร์ต 1 หน้า: ใส่อะไรบ้างให้ r...       th
# 43  title: คำถามสัมภาษณ์ Behavioral สำหรับสาย Data...       th
# 44  title: แนะนำ GitHub สำหรับพอร์ตสาย Data: จัด r...       th
# 45  title: ฝึกทำ Data Cleaning: เทคนิคจัดการ missi...       th
# 46  title: Portfolio Project: วิเคราะห์ยอดขาย + สร...       th
# 47  title: SQL Window Functions แบบที่ใช้จริงในงาน...       th
# 48  title: เตรียมตัวสหกิจ: วิธีเลือกหัวข้อโปรเจกต์...       th
# 49  title: How-to: เตรียมพอร์ตให้ผ่าน ATS สำหรับสา...       th
# 50  title: Mini Project: วิเคราะห์ churn แบบง่ายเพ...       th
# 51  title: Checklist ก่อนส่งสมัครฝึกงาน: พอร์ต เรซ...       th
# 52  title: Data Analyst Intern: ตัวอย่างโจทย์ Take...       th
# 53  title: เริ่มต้น Machine Learning แบบไม่หลงทาง:...       th
# 54  title: SQL + Business Thinking: แปลงคำถามธุรกิ...       th
# 55  title: สาย Data ควรมีโปรเจกต์กี่ชิ้นในพอร์ต แล...       th
# 56  title: SQL Interview Questions for Entry-Level...       en
# 57  title: How to Build a Strong Data Analytics Po...       en
# 58  title: Data Analyst Internship Interview Prep:...       en
# 59  title: A/B Testing Basics for Product Analytic...       en
#
#                                                   url     feed_id
# 0   https://example.com/th/university-admission-sc...  TH_UNI_041
# 1      https://example.com/th/new-university-programs  TH_UNI_042
# 2              https://example.com/th/academic-events  TH_UNI_043
# 3              https://example.com/th/semester-policy  TH_UNI_044
# 4   https://example.com/th/undergraduate-research-...  TH_UNI_045
# 5         https://example.com/th/student-welfare-news  TH_UNI_046
# 6     https://example.com/th/elective-selection-guide  TH_UNI_047
# 7          https://example.com/th/university-industry  TH_UNI_048
# 8          https://example.com/th/university-calendar  TH_UNI_049
# 9      https://example.com/th/higher-education-policy  TH_UNI_050
# 10         https://example.com/th/biotech-career-path  TH_BIO_051
# 11          https://example.com/th/biotech-foundation  TH_BIO_052
# 12  https://example.com/th/biotech-undergrad-research  TH_BIO_053
# 13          https://example.com/th/biotech-internship  TH_BIO_054
# 14          https://example.com/th/biotech-lab-skills  TH_BIO_055
# 15   https://example.com/th/biotech-to-bioinformatics  TH_BIO_056
# 16          https://example.com/th/biotech-curriculum  TH_BIO_057
# 17         https://example.com/th/bio-portfolio-guide  TH_BIO_058
# 18      https://example.com/th/biotech-industry-trend  TH_BIO_059
# 19           https://example.com/th/graduate-bio-prep  TH_BIO_060
# 20  https://example.com/th/undergraduate-scholarships  TH_SCH_031
# 21  https://example.com/th/scholarship-documents-g...  TH_SCH_032
# 22  https://example.com/th/exchange-scholarship-guide  TH_SCH_033
# 23     https://example.com/th/sop-scholarship-writing  TH_SCH_034
# 24  https://example.com/th/graduate-scholarship-sc...  TH_SCH_035
# 25  https://example.com/th/internal-scholarship-ch...  TH_SCH_036
# 26       https://example.com/th/scholarship-interview  TH_SCH_037
# 27  https://example.com/th/student-finance-scholar...  TH_SCH_038
# 28  https://example.com/th/undergraduate-research-...  TH_SCH_039
# 29          https://example.com/th/choose-scholarship  TH_SCH_040
# 30  https://example.com/th/data-analyst-portfolio-...     TH_F001
# 31     https://example.com/th/dashboard-project-ideas     TH_F002
# 32  https://example.com/th/interview-data-analyst-...     TH_F003
# 33   https://example.com/th/data-internship-checklist     TH_F004
# 34        https://example.com/th/data-analyst-roadmap     TH_F005
# 35      https://example.com/th/statistics-for-analyst     TH_F006
# 36   https://example.com/th/storytelling-data-project     TH_F007
# 37      https://example.com/th/sql-interview-practice     TH_F008
# 38     https://example.com/th/python-data-project-eda     TH_F009
# 39          https://example.com/th/data-job-hunt-plan     TH_F010
# 40  https://example.com/th/ab-testing-student-project     TH_F011
# 41           https://example.com/th/da-to-ml-projects     TH_F012
# 42  https://example.com/th/one-page-portfolio-stru...     TH_F013
# 43   https://example.com/th/behavioral-interview-data     TH_F014
# 44   https://example.com/th/github-for-data-portfolio     TH_F015
# 45    https://example.com/th/data-cleaning-techniques     TH_F016
# 46  https://example.com/th/sales-kpi-dashboard-pro...     TH_F017
# 47        https://example.com/th/sql-window-functions     TH_F018
# 48    https://example.com/th/co-op-project-topic-data     TH_F019
# 49          https://example.com/th/ats-data-portfolio     TH_F020
# 50          https://example.com/th/churn-mini-project     TH_F021
# 51  https://example.com/th/internship-apply-checklist     TH_F022
# 52  https://example.com/th/takehome-data-analyst-i...     TH_F023
# 53          https://example.com/th/ml-starter-roadmap     TH_F024
# 54       https://example.com/th/sql-business-thinking     TH_F025
# 55  https://example.com/th/how-many-projects-portf...     TH_F026
# 56  https://example.com/en/sql-interview-data-analyst     EN_F027
# 57        https://example.com/en/data-portfolio-guide     EN_F028
# 58    https://example.com/en/da-intern-interview-prep     EN_F029
# 59           https://example.com/en/ab-testing-basics     EN_F030

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
query = """
SELECT *
FROM `poc-piloturl-nonprod.gold_layer.interactions`
"""
df = client.query(query).to_dataframe()
df
# Out:
# /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#      user_id     feed_id                        ts event_type  dwell_ms
# 0   stu_p001     TH_F001 2026-01-06 13:12:10+00:00       view     52000
# 1   stu_p001     TH_F001 2026-01-06 13:13:05+00:00       like         0
# 2   stu_p001     TH_F001 2026-01-06 13:14:30+00:00    comment         0
# 3   stu_p001     TH_F003 2026-01-05 09:20:11+00:00       view     41000
# 4   stu_p001     TH_F008 2026-01-04 14:05:02+00:00      click         0
# 5   stu_p001     TH_F009 2026-01-04 14:06:40+00:00       view     38000
# 6   stu_p001     TH_F017 2026-01-03 10:15:33+00:00       view     46000
# 7   stu_p001     TH_F017 2026-01-03 10:16:20+00:00      share         0
# 8   stu_p001     TH_F004 2026-01-01 11:35:50+00:00       view     24000
# 9   stu_p002  TH_BIO_051 2026-01-06 08:40:05+00:00       view     47000
# 10  stu_p002  TH_BIO_052 2026-01-05 10:12:44+00:00       view     36000
# 11  stu_p002  TH_BIO_055 2026-01-04 09:00:12+00:00       view     42000
# 12  stu_p002  TH_BIO_054 2026-01-03 07:55:25+00:00      click         0
# 13  stu_p002  TH_BIO_054 2026-01-03 07:56:10+00:00       view     33000
# 14  stu_p002  TH_SCH_035 2026-01-02 12:30:00+00:00       view     28000
# 15  stu_p002  TH_SCH_035 2026-01-02 12:31:10+00:00    comment         0
# 16  stu_p003     TH_F006 2026-01-06 07:20:15+00:00       view     22000
# 17  stu_p003     TH_F007 2026-01-05 06:50:44+00:00       view     31000
# 18  stu_p003     TH_F007 2026-01-05 06:51:30+00:00      share         0
# 19  stu_p003     TH_F011 2026-01-03 12:11:09+00:00       view     27000
# 20  stu_p003     TH_F008 2026-01-02 09:44:01+00:00       view     34000
# 21  stu_p003     TH_F003 2026-01-01 15:03:18+00:00      click         0
# 22  stu_p003     TH_F003 2026-01-01 15:04:10+00:00       view     25000
# 23  stu_p004     TH_F010 2026-01-06 09:10:10+00:00       view     18000
# 24  stu_p004     TH_F020 2026-01-05 10:30:00+00:00       view     14000
# 25  stu_p004     TH_F013 2026-01-04 11:45:12+00:00       view     12000
# 26  stu_p004     TH_F013 2026-01-04 11:46:40+00:00    comment         0
# 27  stu_p004     TH_F022 2026-01-03 08:12:33+00:00      click         0
# 28  stu_p004     TH_F022 2026-01-03 08:13:20+00:00       view      9000
# 29  stu_p005     TH_F005 2026-01-06 16:02:05+00:00       view     21000
# 30  stu_p005     TH_F005 2026-01-06 16:02:45+00:00       like         0
# 31  stu_p005     TH_F005 2026-01-06 16:03:30+00:00      share         0
# 32  stu_p005     TH_F009 2026-01-04 09:00:00+00:00       view     16000
# 33  stu_p006  TH_BIO_058 2026-01-06 07:35:12+00:00       view     39000
# 34  stu_p006  TH_BIO_054 2026-01-05 09:14:40+00:00       view     25000
# 35  stu_p006  TH_BIO_055 2026-01-04 10:00:00+00:00       view     28000
# 36  stu_p006  TH_SCH_033 2026-01-03 12:02:22+00:00       view     23000
# 37  stu_p006  TH_SCH_033 2026-01-03 12:03:40+00:00    comment         0
# 38  stu_p006  TH_SCH_036 2026-01-02 08:33:41+00:00      click         0
# 39  stu_p007     TH_F006 2026-01-06 10:05:55+00:00       view      9000
# 40  stu_p007     TH_F012 2026-01-04 09:10:10+00:00       view      7000
# 41  stu_p007  TH_BIO_051 2026-01-02 11:30:00+00:00      click         0
# 42  stu_p007  TH_BIO_051 2026-01-02 11:31:10+00:00    comment         0
# 43  stu_p008  TH_UNI_043 2026-01-06 06:40:00+00:00       view     12000
# 44  stu_p008  TH_UNI_049 2026-01-05 07:20:10+00:00       view      8000
# 45  stu_p008  TH_SCH_031 2026-01-04 08:30:30+00:00       view     15000
# 46  stu_p008  TH_SCH_031 2026-01-04 08:31:20+00:00      share         0
# 47  stu_p008  TH_SCH_036 2026-01-03 09:11:11+00:00      click         0
# 48  stu_p009     EN_F028 2026-01-06 12:10:10+00:00       view     36000
# 49  stu_p009     EN_F027 2026-01-05 08:20:30+00:00       view     30000
# 50  stu_p009     EN_F027 2026-01-05 08:21:45+00:00    comment         0
# 51  stu_p009     EN_F029 2026-01-04 07:00:00+00:00      click         0
# 52  stu_p009     EN_F029 2026-01-04 07:01:00+00:00       view     24000
# 53  stu_p010     TH_F015 2026-01-06 23:59:00+00:00       view     60000
# 54  stu_p010     TH_F015 2026-01-07 00:00:20+00:00      share         0
# 55  stu_p010  TH_BIO_055 2026-01-06 23:59:40+00:00       like         0
